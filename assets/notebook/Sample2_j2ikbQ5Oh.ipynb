# %%
import pandas as pd

df_data_1 = pd.read_csv('/project_data/data_asset/POC_PASSENGER.csv')
df_data_1.head()
# Out:
#   PassengerID        UIN                   Name         DOB  Nationality  \
# 0   P00000001  S4419646H     James Lim Wei Ming    6/1/1994  Singaporean
# 1   P00000002  S8010049C      Jamie Tan Lia Yen    7/1/1980  Singaporean
# 2   P00000003  S8646628G       Aaish bin Ashraf    9/2/1986  Singaporean
# 3   P00000004  S8189655J  Sahheeda binti Faalih   3/10/1981  Singaporean
# 4   P00000005  F8282708X       Hijau binti Gana  19/12/1982    Malaysian
#
#   Gender  Picture
# 0      M      NaN
# 1      M      NaN
# 2      M      NaN
# 3      F      NaN
# 4      F      NaN

# %%
df_data_1.corr()
# Out:
#          Picture
# Picture      NaN

# %%
df_data_1.info
# Out:
# <bound method DataFrame.info of    PassengerID         UIN                   Name         DOB  Nationality  \
# 0    P00000001   S4419646H     James Lim Wei Ming    6/1/1994  Singaporean
# 1    P00000002   S8010049C      Jamie Tan Lia Yen    7/1/1980  Singaporean
# 2    P00000003   S8646628G       Aaish bin Ashraf    9/2/1986  Singaporean
# 3    P00000004   S8189655J  Sahheeda binti Faalih   3/10/1981  Singaporean
# 4    P00000005   F8282708X       Hijau binti Gana  19/12/1982    Malaysian
# 5    P00000006   G8856141X         Jeremy Harahap   20/1/1988   Indonesian
# 6    P00000007  J401278562          Arjun Acharya   10/2/1992       Indian
# 7    P00000008   S9135544B             Darryl Lim   20/1/1991  Singaporean
# 8    P00000009   S9196522D             Darren Lee   20/1/1991  Singaporean
# 9    P00000010   S9343950C              Jamie Soh   20/1/1993  Singaporean
# 10   P00000011   T0801664F            Eleanor Tan   18/2/2008  Singaporean
# ...

# %%
df_data_1.describe
# Out:
# <bound method NDFrame.describe of    PassengerID         UIN                   Name         DOB  Nationality  \
# 0    P00000001   S4419646H     James Lim Wei Ming    6/1/1994  Singaporean
# 1    P00000002   S8010049C      Jamie Tan Lia Yen    7/1/1980  Singaporean
# 2    P00000003   S8646628G       Aaish bin Ashraf    9/2/1986  Singaporean
# 3    P00000004   S8189655J  Sahheeda binti Faalih   3/10/1981  Singaporean
# 4    P00000005   F8282708X       Hijau binti Gana  19/12/1982    Malaysian
# 5    P00000006   G8856141X         Jeremy Harahap   20/1/1988   Indonesian
# 6    P00000007  J401278562          Arjun Acharya   10/2/1992       Indian
# 7    P00000008   S9135544B             Darryl Lim   20/1/1991  Singaporean
# 8    P00000009   S9196522D             Darren Lee   20/1/1991  Singaporean
# 9    P00000010   S9343950C              Jamie Soh   20/1/1993  Singaporean
# 10   P00000011   T0801664F            Eleanor Tan   18/2/2008  Singaporean
# ...
